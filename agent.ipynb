# %%
import uuid
import os
import base64
import openai
from dotenv import load_dotenv
from PIL import Image
from io import BytesIO
import requests
from textmodel_demo import get_response
import re

# %%
load_dotenv()

# Initialize OpenAI client
client = openai.OpenAI(
    api_key=os.environ.get("SAMBANOVA_API_KEY"),
    base_url="https://api.sambanova.ai/v1",
)

# %%
from langchain_community.document_loaders import WebBaseLoader

loader = WebBaseLoader("https://en.wikipedia.org/wiki/Sea_surface_temperature")
docs = loader.load()

# %%
docs
# Out:
# [Document(metadata={'source': 'https://en.wikipedia.org/wiki/2023_deaths_in_the_United_States', 'title': '2023 deaths in the United States - Wikipedia', 'language': 'en'}, page_content='\n\n\n\n2023 deaths in the United States - Wikipedia\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nJump to content\n\n\n\n\n\n\n\nMain menu\n\n\n\n\n\nMain menu\nmove to sidebar\nhide\n\n\n\n\t\tNavigation\n\t\n\n\nMain pageContentsCurrent eventsRandom articleAbout WikipediaContact us\n\n\n\n\n\n\t\tContribute\n\t\n\n\nHelpLearn to editCommunity portalRecent changesUpload file\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nSearch\n\n\n\n\n\n\n\n\n\n\n\nSearch\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nAppearance\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nDonate\n\nCreate account\n\nLog in\n\n\n\n\n\n\n\n\nPersonal tools\n\n\n\n\n\nDonate Create account Log in\n\n\n\n\n\n\t\tPages for logged out editors learn more\n\n\n\nContributionsTalk\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nContents\nmove to sidebar\nhide\n\n\n\n\n(Top)\n\n\n\n\n\n1\nJanuary\n\n\n\n\n\n\n\n\n2\nFebruary\n\n\n\n\n\n\n\n\n3\nMarch\n\n\n\n\n\n\n\n\n4\nApril\n\n\n\n\n\n\n\n\n5\nMay\n\n\n\n\n\n\n\n\n6\nJune\n\n\n\n\n\n\n\n\n7\nJuly\n\n\n\n\n\n\n\n\n8\nAugust\n\n\n\n\n\n\n\n\n9\nSeptember\n\n\n\n\n\n\n\n\n10\nOctober\n\n\n\n\n\n\n\n\n11\nNovember\n\n\n\n\n\n\n\n\n12\nDecember\n\n\n\n\n\n\n\n\n13\nReferences\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nToggle the table of contents\n\n\n\n\n\n\n\n2023 deaths in the United States\n\n\n\n1 language\n\n\n\n\nمصرى\n\nEdit links\n\n\n\n\n\n\n\n\n\n\n\nArticleTalk\n\n\n\n\n\nEnglish\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nReadEditView history\n\n\n\n\n\n\n\nTools\n\n\n\n\n\nTools\nmove to sidebar\nhide\n\n\n\n\t\tActions\n\t\n\n\nReadEditView history\n\n\n\n\n\n\t\tGeneral\n\t\n\n\nWhat links hereRelated changesUpload fileSpecial pagesPermanent linkPage informationCite this pageGet shortened URLDownload QR code\n\n\n\n\n\n\t\tPrint/export\n\t\n\n\nDownload as PDFPrintable version\n\n\n\n\n\n\t\tIn other projects\n\t\n\n\nWikidata item\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nAppearance\nmove to sidebar\nhide\n\n\n\n\n\n\n\n\n\n\nFrom Wikipedia, the free encyclopedia\n\n\nList of notable US deaths in a year\nFurther information: Category:2023 deaths\n\n\n\n\n←\n\n2022\n2021\n2020\n\n\n\n\n2023 in the United States\n\n\n→\n\n2024\n2025\n2026\n\n\nDecades:\n2000s\n2010s\n2020s\n2030s\n\nSee also:\n\nHistory of the United States (2008–present)\nTimeline of United States history (2010–present)\nList of years in the United States\n\nMain articles: 2023 in the United States and Deaths in 2023\nThe following notable deaths in the United States occurred in 2023. Names are reported under the date of death, in alphabetical order as set out in WP:NAMESORT.\nA typical entry reports information in the following sequence:\nName, age, country of citizenship at birth and subsequent nationality (if applicable), what subject was noted for, year of birth (if known), and reference.\n\n\n\nJanuary[edit]\nMain article: Deaths in January 2023\nGangsta Boo\nKen Block\nWalter Cunningham\nRussell Banks\nAdam Rich\nMelinda Dillon\nCarole Cook\nCharles Kimbrough\nLisa Marie Presley\nRobbie Knievel\nLloyd Morrisett\nTed Savage\nFrank Thomas\nJay Briscoe\nDavid Crosby\nSal Bando\nBill Schonely\nLance Kerwin\nCindy Williams\nLisa Loring\nTom Verlaine\nAnnie Wersching\nBobby Beathard\nDavid Durenberger\nJanuary 1\nMartin Davis, 94, mathematician (Davis–Putnam algorithm) (b. 1928)[1]\nGangsta Boo, 43, rapper (Three 6 Mafia) (b. 1979)[2]\nEdith Lank, 96, author and advice columnist (b. 1926)[3]\nSebastian Marino, 57, guitarist (Overkill, Anvil) (b. 1965)[4]\nArt McNally, 97, Hall of Fame football official, director of officiating for the NFL (1968–1991) (b. 1925)[5]\nKelly Monteith, 80, comedian (b. 1942)[6]\nMeenakshi Narain, 58, experimental physicist (b. 1964)[7]\nEdith Pearlman, 86, short story writer (b. 1936)[8]\nFred White, 67, Hall of Fame drummer (Earth, Wind & Fir ...

# %%
from langchain_community.llms.sambanova import SambaNovaCloud

llm = SambaNovaCloud(
    model="Meta-Llama-3.1-8B-Instruct",
    max_tokens_to_generate=1000,
    temperature=0.01,
    # top_k = 50,
    # top_p = 1.0
)

# %%
from langchain_core.output_parsers import StrOutputParser
from langchain_core.prompts import ChatPromptTemplate

map_prompt = ChatPromptTemplate.from_messages(
    [("system", "Write a concise summary of the following:\\n\\n{context}")]
)

map_chain = map_prompt | llm | StrOutputParser()

# %%
from langchain import hub

map_prompt = hub.pull("rlm/map-prompt")

# %%
# Also available via the hub: `hub.pull("rlm/reduce-prompt")`
reduce_template = """
The following is a set of summaries:
{docs}
Take these and distill it into a final, consolidated summary
of the main themes.
"""

reduce_prompt = ChatPromptTemplate([("human", reduce_template)])

reduce_chain = reduce_prompt | llm | StrOutputParser()

# %%
from langchain_text_splitters import CharacterTextSplitter,RecursiveCharacterTextSplitter

text_splitter = RecursiveCharacterTextSplitter.from_tiktoken_encoder(
    chunk_size=100,
    chunk_overlap=0,
)
split_docs = text_splitter.split_documents(docs)
print(f"Generated {len(split_docs)} documents.")
# Out:
# Generated 155 documents.

# %%
import operator
from typing import Annotated, List, Literal, TypedDict

from langchain.chains.combine_documents.reduce import (
    acollapse_docs,
    split_list_of_docs,
)
from langchain_core.documents import Document
from langgraph.constants import Send
from langgraph.graph import END, START, StateGraph

token_max = 1000


def length_function(documents: List[Document]) -> int:
    """Get number of tokens for input contents."""
    return sum(llm.get_num_tokens(doc.page_content) for doc in documents)


# This will be the overall state of the main graph.
# It will contain the input document contents, corresponding
# summaries, and a final summary.
class OverallState(TypedDict):
    # Notice here we use the operator.add
    # This is because we want combine all the summaries we generate
    # from individual nodes back into one list - this is essentially
    # the "reduce" part
    contents: List[str]
    summaries: Annotated[list, operator.add]
    collapsed_summaries: List[Document]
    final_summary: str


# This will be the state of the node that we will "map" all
# documents to in order to generate summaries
class SummaryState(TypedDict):
    content: str


# Here we generate a summary, given a document
async def generate_summary(state: SummaryState):
    response = await map_chain.ainvoke(state["content"])
    return {"summaries": [response]}


# Here we define the logic to map out over the documents
# We will use this an edge in the graph
def map_summaries(state: OverallState):
    # We will return a list of `Send` objects
    # Each `Send` object consists of the name of a node in the graph
    # as well as the state to send to that node
    return [
        Send("generate_summary", {"content": content}) for content in state["contents"]
    ]


def collect_summaries(state: OverallState):
    return {
        "collapsed_summaries": [Document(summary) for summary in state["summaries"]]
    }


# Add node to collapse summaries
async def collapse_summaries(state: OverallState):
    doc_lists = split_list_of_docs(
        state["collapsed_summaries"], length_function, token_max
    )
    results = []
    for doc_list in doc_lists:
        results.append(await acollapse_docs(doc_list, reduce_chain.ainvoke))

    return {"collapsed_summaries": results}


# This represents a conditional edge in the graph that determines
# if we should collapse the summaries or not
def should_collapse(
    state: OverallState,
) -> Literal["collapse_summaries", "generate_final_summary"]:
    num_tokens = length_function(state["collapsed_summaries"])
    if num_tokens > token_max:
        return "collapse_summaries"
    else:
        return "generate_final_summary"


# Here we will generate the final summary
async def generate_final_summary(state: OverallState):
    response = await reduce_chain.ainvoke(state["collapsed_summaries"])
    return {"final_summary": response}


# Construct the graph
# Nodes:
graph = StateGraph(OverallState)
graph.add_node("generate_summary", generate_summary)  # same as before
graph.add_node("collect_summaries", collect_summaries)
graph.add_node("collapse_summaries", collapse_summaries)
graph.add_node("generate_final_summary", generate_final_summary)

# Edges:
graph.add_conditional_edges(START, map_summaries, ["generate_summary"])
graph.add_edge("generate_summary", "collect_summaries")
graph.add_conditional_edges("collect_summaries", should_collapse)
graph.add_conditional_edges("collapse_summaries", should_collapse)
graph.add_edge("generate_final_summary", END)

app = graph.compile()

# %%
async for step in app.astream(
    {"contents": [doc.page_content for doc in split_docs]},
    {"recursion_limit": 5},
):
    print(list(step.keys()))
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[45], line 1
# ----> 1 async for step in app.astream(
#       2     {"contents": [doc.page_content for doc in split_docs]},
#       3     {"recursion_limit": 5},
#       4 ):
#       5     print(list(step.keys()))
#
# File c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\langgraph\pregel\__init__.py:1865, in Pregel.astream(self, input, config, stream_mode, output_keys, interrupt_before, interrupt_after, debug, subgraphs)
#    1859 # Similarly to Bulk Synchronous Parallel / Pregel model
#    1860 # computation proceeds in steps, while there are channel updates
#    1861 # channel updates from step N are only visible in step N+1
#    1862 # channels are guaranteed to be immutable for the duration of the step,
#    1863 # with channel updates applied only at the transition between steps
#    1864 while loop.tick(input_keys=self.input_channels):
# -> 1865     async for _ in runner.atick(
#    1866         loop.tasks.values(),
#    1867         timeout=self.step_timeout,
#    1868         retry_policy=self.retry_policy,
#    1869         get_waiter=get_waiter,
#    1870     ):
#    1871         # emit output
#    1872         for o in output():
#    1873             yield o
#
# File c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\langgraph\pregel\runner.py:287, in PregelRunner.atick(self, tasks, reraise, timeout, retry_policy, get_waiter)
#     285     fut.cancel()
#     286 # panic on failure or timeout
# --> 287 _panic_or_proceed(
#     288     done_futures.union(f for f, t in futures.items() if t is not None),
#     289     timeout_exc_cls=asyncio.TimeoutError,
#     290     panic=reraise,
#     291 )
#
# File c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\langgraph\pregel\runner.py:367, in _panic_or_proceed(futs, timeout_exc_cls, panic)
#     365 # raise the exception
#     366 if panic:
# --> 367     raise exc
#     368 else:
#     369     return
#
# File c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\langgraph\pregel\retry.py:118, in arun_with_retry(task, retry_policy, stream, writer)
#     116         pass
#     117 else:
# --> 118     await task.proc.ainvoke(task.input, config)
#     119 # if successful, end
#     120 break
#
# File c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\langgraph\utils\runnable.py:453, in RunnableSeq.ainvoke(self, input, config, **kwargs)
#     451     coro = step.ainvoke(input, config)
#     452 if ASYNCIO_ACCEPTS_CONTEXT:
# --> 453     input = await asyncio.create_task(coro, context=context)
#     454 else:
#     455     input = await asyncio.create_task(coro)
#
# File c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\langgraph\utils\runnable.py:236, in RunnableCallable.ainvoke(self, input, config, **kwargs)
#     234 if ASYNCIO_ACCEPTS_CONTEXT:
#     235     coro = cast(Coroutine[None, None, Any], self.afunc(input, **kwargs))
# --> 236     ret = await asyncio.create_task(coro, context=context)
#     237 else:
#     238     ret = await self.afunc(input, **kwargs)
#
# Cell In[43], line 42, in generate_summary(state)
#      41 async def generate_summary(state: SummaryState):
# ---> 42     response = await map_chain.ainvoke(state["content"])
#      43     return {"summaries": [response]}
#
# File c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\langchain_core\runnables\base.py:3066, in RunnableSequence.ainvoke(self, input, config, **kwargs)
#    3064     part = functools.partial(step.ainvoke, input, config)
#    3065 if asyncio_accepts_context():
# -> 3066     input = await asyncio.create_task(part(), context=context)  # type: ignore
#    3067 else:
#    3068     input = await asyncio.create_task(part())
#
# File c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\langchain_core\language_models\llms.py:413, in BaseLLM.ainvoke(self, input, config, stop, **kwargs)
#     404 async def ainvoke(
#     405     self,
#     406     input: LanguageModelInput,
#    (...)
#     410     **kwargs: Any,
#     411 ) -> str:
#     412     config = ensure_config(config)
# --> 413     llm_result = await self.agenerate_prompt(
#     414         [self._convert_input(input)],
#     415         stop=stop,
#     416         callbacks=config.get("callbacks"),
#     417         tags=config.get("tags"),
#     418         metadata=config.get("metadata"),
#     419         run_name=config.get("run_name"),
#     420         run_id=config.pop("run_id", None),
#     421         **kwargs,
#     422     )
#     423     return llm_result.generations[0][0].text
#
# File c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\langchain_core\language_models\llms.py:765, in BaseLLM.agenerate_prompt(self, prompts, stop, callbacks, **kwargs)
#     757 async def agenerate_prompt(
#     758     self,
#     759     prompts: list[PromptValue],
#    (...)
#     762     **kwargs: Any,
#     763 ) -> LLMResult:
#     764     prompt_strings = [p.to_string() for p in prompts]
# --> 765     return await self.agenerate(
#     766         prompt_strings, stop=stop, callbacks=callbacks, **kwargs
#     767     )
#
# File c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\langchain_core\language_models\llms.py:1190, in BaseLLM.agenerate(self, prompts, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#    1173     run_managers = await asyncio.gather(
#    1174         *[
#    1175             callback_manager.on_llm_start(
#    (...)
#    1187         ]
#    1188     )
#    1189     run_managers = [r[0] for r in run_managers]  # type: ignore[misc]
# -> 1190     output = await self._agenerate_helper(
#    1191         prompts,
#    1192         stop,
#    1193         run_managers,  # type: ignore[arg-type]
#    1194         bool(new_arg_supported),
#    1195         **kwargs,  # type: ignore[arg-type]
#    1196     )
#    1197     return output
#    1198 if len(missing_prompts) > 0:
#
# File c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\langchain_core\language_models\llms.py:1030, in BaseLLM._agenerate_helper(self, prompts, stop, run_managers, new_arg_supported, **kwargs)
#    1023 except BaseException as e:
#    1024     await asyncio.gather(
#    1025         *[
#    1026             run_manager.on_llm_error(e, response=LLMResult(generations=[]))
#    1027             for run_manager in run_managers
#    1028         ]
#    1029     )
# -> 1030     raise e
#    1031 flattened_outputs = output.flatten()
#    1032 await asyncio.gather(
#    1033     *[
#    1034         run_manager.on_llm_end(flattened_output)
#    (...)
#    1038     ]
#    1039 )
#
# File c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\langchain_core\language_models\llms.py:1014, in BaseLLM._agenerate_helper(self, prompts, stop, run_managers, new_arg_supported, **kwargs)
#    1004 async def _agenerate_helper(
#    1005     self,
#    1006     prompts: list[str],
#    (...)
#    1010     **kwargs: Any,
#    1011 ) -> LLMResult:
#    1012     try:
#    1013         output = (
# -> 1014             await self._agenerate(
#    1015                 prompts,
#    1016                 stop=stop,
#    1017                 run_manager=run_managers[0] if run_managers else None,
#    1018                 **kwargs,
#    1019             )
#    1020             if new_arg_supported
#    1021             else await self._agenerate(prompts, stop=stop)
#    1022         )
#    1023     except BaseException as e:
#    1024         await asyncio.gather(
#    1025             *[
#    1026                 run_manager.on_llm_error(e, response=LLMResult(generations=[]))
#    1027                 for run_manager in run_managers
#    1028             ]
#    1029         )
#
# File c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\langchain_core\language_models\llms.py:1521, in LLM._agenerate(self, prompts, stop, run_manager, **kwargs)
#    1518 new_arg_supported = inspect.signature(self._acall).parameters.get("run_manager")
#    1519 for prompt in prompts:
#    1520     text = (
# -> 1521         await self._acall(prompt, stop=stop, run_manager=run_manager, **kwargs)
#    1522         if new_arg_supported
#    1523         else await self._acall(prompt, stop=stop, **kwargs)
#    1524     )
#    1525     generations.append([Generation(text=text)])
#    1526 return LLMResult(generations=generations)
#
# File c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\langchain_core\language_models\llms.py:1480, in LLM._acall(self, prompt, stop, run_manager, **kwargs)
#    1455 async def _acall(
#    1456     self,
#    1457     prompt: str,
#    (...)
#    1460     **kwargs: Any,
#    1461 ) -> str:
#    1462     """Async version of the _call method.
#    1463
#    1464     The default implementation delegates to the synchronous _call method using
#    (...)
#    1478         The model output as a string. SHOULD NOT include the prompt.
#    1479     """
# -> 1480     return await run_in_executor(
#    1481         None,
#    1482         self._call,
#    1483         prompt,
#    1484         stop,
#    1485         run_manager.get_sync() if run_manager else None,
#    1486         **kwargs,
#    1487     )
#
# File c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\langchain_core\runnables\config.py:588, in run_in_executor(executor_or_config, func, *args, **kwargs)
#     584         raise RuntimeError from exc
#     586 if executor_or_config is None or isinstance(executor_or_config, dict):
#     587     # Use default executor with context copied from current context
# --> 588     return await asyncio.get_running_loop().run_in_executor(
#     589         None,
#     590         cast(Callable[..., T], partial(copy_context().run, wrapper)),
#     591     )
#     593 return await asyncio.get_running_loop().run_in_executor(executor_or_config, wrapper)
#
# File c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\concurrent\futures\thread.py:58, in _WorkItem.run(self)
#      55     return
#      57 try:
# ---> 58     result = self.fn(*self.args, **self.kwargs)
#      59 except BaseException as exc:
#      60     self.future.set_exception(exc)
#
# File c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\langchain_core\runnables\config.py:579, in run_in_executor.<locals>.wrapper()
#     577 def wrapper() -> T:
#     578     try:
# --> 579         return func(*args, **kwargs)
#     580     except StopIteration as exc:
#     581         # StopIteration can't be set on an asyncio.Future
#     582         # it raises a TypeError and leaves the Future pending forever
#     583         # so we need to convert it to a RuntimeError
#     584         raise RuntimeError from exc
#
# File c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\langchain_community\llms\sambanova.py:841, in SambaNovaCloud._call(self, prompt, stop, run_manager, **kwargs)
#     837         completion += chunk.text
#     839     return completion
# --> 841 response = self._handle_request(prompt, stop, streaming=False)
#     842 completion = self._process_response(response)
#     843 return completion
#
# File c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\langchain_community\llms\sambanova.py:728, in SambaNovaCloud._handle_request(self, prompt, stop, streaming)
#     723     response = http_session.post(
#     724         self.sambanova_url, headers=headers, json=data, stream=False
#     725     )
#     727 if response.status_code != 200:
# --> 728     raise RuntimeError(
#     729         f"Sambanova / complete call failed with status code "
#     730         f"{response.status_code}."
#     731         f"{response.text}."
#     732     )
#     733 return response
#
# RuntimeError: Sambanova / complete call failed with status code 429.{"error":{"code":null,"message":"Rate limit exceeded","param":null,"type":"rate_limit_exceeded"}}
# .
